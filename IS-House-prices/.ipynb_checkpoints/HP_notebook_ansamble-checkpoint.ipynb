# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy import stats
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from pyod.models.iforest import IForest
from sklearn.cluster import OPTICS
from scipy.special import boxcox, inv_boxcox
import umap
# %matplotlib inline

# %%
features['YrSold'].astype(int) - features['YearRemodAdd'].astype(int)

# %%
test.iloc[835][['YrSold', 'YearRemodAdd']]
# Out:
# YrSold          7.60489
# YearRemodAdd    7.60539
# Name: 835, dtype: object

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print(len(train), len(test))
# Out:
# 1460 1459

# %%
train.drop('Id', inplace = True, axis = 1)
test.drop('Id', inplace = True, axis = 1)

# %%
target = train['SalePrice']

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(train.corr(), cmap = 'magma', square=True)
# Out:
# <AxesSubplot:>

# %%
train.plot.scatter('SalePrice', 'MiscVal', alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='MiscVal'>

# %%
train.plot.scatter('SalePrice', 'GrLivArea', alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='GrLivArea'>

# %%
train.plot.scatter('SalePrice', 'TotalBsmtSF', alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='TotalBsmtSF'>

# %%
kurt_raw = round(stats.kurtosis(target), 2)
skewness_raw = round(stats.skew(target), 2)
Shapiro_Wilk_raw = round(stats.shapiro(target)[0], 3)
sns.histplot(data = train, x = 'SalePrice', kde = 'True')
print(f'Skewness: {skewness_raw} \nKurtosis: {kurt_raw} \nShapiro_Wilk:{Shapiro_Wilk_raw}')
# Out:
# Skewness: 1.88
# Kurtosis: 6.51
# Shapiro_Wilk:0.87

# %%
features = pd.concat([train.drop('SalePrice', axis = 1), test])

# %%
print("Unique values in each categorical column:")
for col in features.select_dtypes(include=[object]):
    print(col,":", features[col].unique())
# Out:
# Unique values in each categorical column:
# MSZoning : ['RL' 'RM' 'C (all)' 'FV' 'RH' nan]
# Street : ['Pave' 'Grvl']
# Alley : [nan 'Grvl' 'Pave']
# LotShape : ['Reg' 'IR1' 'IR2' 'IR3']
# LandContour : ['Lvl' 'Bnk' 'Low' 'HLS']
# Utilities : ['AllPub' 'NoSeWa' nan]
# LotConfig : ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# LandSlope : ['Gtl' 'Mod' 'Sev']
# Neighborhood : ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Condition1 : ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Condition2 : ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# BldgType : ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# HouseStyle : ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# RoofStyle : ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ...

# %% [markdown]
# Анализ целевой

# %% [markdown]
# Преобразование целевой: Box-Cox

# %%
boxcox_target, lmbda  = stats.boxcox(target)
boxcox_kurt_raw = round(stats.kurtosis(boxcox_target),3)
boxcox_skewness_raw = round(stats.skew(boxcox_target), 3)
boxcox_Shapiro_W = round(stats.shapiro(boxcox_target)[0], 3)
sns.histplot(boxcox_target, kde = 'True')
print(f'Skewness: {boxcox_skewness_raw} \nKurtosis: {boxcox_kurt_raw}\nShapiro_Wilk: {boxcox_Shapiro_W}')
# Для инверсии: scipy.special.inv_boxcox scipy.special.inv_boxcox()
# Out:
# Skewness: -0.009
# Kurtosis: 0.871
# Shapiro_Wilk: 0.992

# %%
train['SalePrice']= boxcox_target

# %% [markdown]
# Fill NA

# %%
missed = {}
for col in features.columns:
    if features[col].isnull().any():
        missed.update({col: [round(features[col].isnull().sum()/len(train)*100,2), features[col].dtype]})
sorted(missed.items(), key = lambda x: x[1], reverse=True)
# Out:
# [('PoolQC', [199.25, dtype('O')]),
#  ('MiscFeature', [192.74, dtype('O')]),
#  ('Alley', [186.37, dtype('O')]),
#  ('Fence', [160.82, dtype('O')]),
#  ('FireplaceQu', [97.26, dtype('O')]),
#  ('LotFrontage', [33.29, dtype('float64')]),
#  ('GarageFinish', [10.89, dtype('O')]),
#  ('GarageQual', [10.89, dtype('O')]),
#  ('GarageCond', [10.89, dtype('O')]),
#  ('GarageYrBlt', [10.89, dtype('float64')]),
#  ('GarageType', [10.75, dtype('O')]),
#  ('BsmtCond', [5.62, dtype('O')]),
#  ('BsmtExposure', [5.62, dtype('O')]),
#  ('BsmtQual', [5.55, dtype('O')]),
#  ('BsmtFinType2', [5.48, dtype('O')]),
#  ('BsmtFinType1', [5.41, dtype('O')]),
#  ('MasVnrType', [1.64, dtype('O')]),
#  ('MasVnrArea', [1.58, dtype('float64')]),
#  ('MSZoning', [0.27, dtype('O')]),
#  ('Utilities', [0.14, dtype('O')]),
#  ('Functional', [0.14, dtype('O')]),
#  ('BsmtFullBath', [0.14, dtype('float64')]),
#  ('BsmtHalfBath', [0.14, dtype('float64')]),
#  ('Exterior1st', [0.07, dtype('O')]),
# ...

# %% [markdown]
# String fill NA

# %%
fill_none_strs = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 
                  'GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 'MasVnrType',
                  ]
fill_mod_strs = ['MSZoning', 'Utilities', 'Functional', 'Exterior1st', 'Exterior2nd', 'Electrical', 'KitchenQual', 
                 'SaleType' 
                ]
fill_zer_ints = ['LotFrontage', 'GarageYrBlt', 'MasVnrArea', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtFinSF1', 'BsmtFinSF2',
                'GarageCars', 'GarageArea', 'BsmtUnfSF', 'TotalBsmtSF']
def fill_strs(df):
    for cols in fill_none_strs:
        df[cols] = df[cols].fillna('None')
    for cols in fill_mod_strs:
        df[cols] = df[cols].fillna(df[cols].mode()[0])
    return df
def fill_ints(df):
    for cols in fill_zer_ints:
        df[cols] = df[cols].fillna(0)
    return(df)

# %%
features = fill_strs(features)
features = fill_ints(features)
train = fill_strs(train)
train = fill_ints(train)
test = fill_strs(test)
test = fill_ints(test)

# %%
numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_cols = features.select_dtypes(numeric_dtypes).columns

# %%
salecorr = sorted(train.corr()['SalePrice'].reset_index().values.tolist(), key = lambda x:x[1], reverse = True)
top10_corr = []
for i in salecorr[1:11]:
    top10_corr.append(i[0])

# %%
clf = IForest(n_jobs=-1, random_state=777, contamination=0.05)
clf.fit(train[top10_corr])
outliers = clf.predict(train[top10_corr])
train['Outlier'] = outliers
Out = pd.Index(['Outlier'])
num_cols_outlier = num_cols.append(Out)
# Out:
# D:\Python\Anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(

# %%
reducer = umap.UMAP()
scaled_umap_data = MinMaxScaler().fit_transform(train[num_cols].values)
embedding = reducer.fit_transform(scaled_umap_data)
plt.scatter(embedding[:, 0], embedding[:, 1], c=outliers)

# %%
train.drop(train[train['Outlier'] == 1].index, axis = 0, inplace = True)
train.drop('Outlier', axis = 1, inplace = True)

# %%
target = train['SalePrice']

# %%
len(target)
# Out:
# 1387

# %%
features = pd.concat([train.drop('SalePrice', axis = 1), test])

# %%
reducer = umap.UMAP()
scaled_umap_data_feat = MinMaxScaler().fit_transform(features[num_cols].values)
embedding_feat = reducer.fit_transform(scaled_umap_data_feat)

# %%
Optics = OPTICS(min_samples=100).fit(embedding_feat)
plt.scatter(embedding_feat[:, 0], embedding_feat[:, 1], c = Optics.labels_)

# %%
set(Optics.labels_)
# Out:
# {-1, 0, 1, 2, 3, 4, 5}

# %%
features['Optics_top10_cor'] = Optics.labels_+2

# %%
features[['YearBuilt', 'YearRemodAdd']].apply(lambda x: x['YearBuilt'] if x['YearBuilt'] > x['YearRemodAdd'] else x['YearRemodAdd'], axis = 1)
# Out:
# 0       2003
# 1       1976
# 2       2002
# 3       1970
# 4       2000
#         ...
# 1454    1970
# 1455    1970
# 1456    1996
# 1457    1992
# 1458    1994
# Length: 2846, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 7))
ax.set_xscale("log")
ax = sns.boxplot(data=features[num_cols] , orient="h", palette="Set1")

# %%
skew_d = {}
for col in num_cols:
        if stats.skew(features[col]) > 0.5:
            skew_d.update({col: stats.skew(features[col])})
sorted(skew_d.items(), key = lambda x: x[1], reverse=True)
# Out:
# [('MiscVal', 22.15367822642918),
#  ('PoolArea', 19.61368656522395),
#  ('LotArea', 13.624939682924516),
#  ('LowQualFinSF', 13.385796936947338),
#  ('3SsnPorch', 11.229705544962778),
#  ('KitchenAbvGr', 4.451528199528828),
#  ('BsmtFinSF2', 4.164017433995429),
#  ('EnclosedPorch', 4.066944456792282),
#  ('BsmtHalfBath', 3.9162790351679724),
#  ('ScreenPorch', 3.8867011875497672),
#  ('MasVnrArea', 2.5520187027582053),
#  ('OpenPorchSF', 2.5138013316409467),
#  ('WoodDeckSF', 1.8243858162127875),
#  ('MSSubClass', 1.3654671051883585),
#  ('1stFlrSF', 1.2333767998361398),
#  ('BsmtFinSF1', 0.9557191016200707),
#  ('GrLivArea', 0.9113815778639948),
#  ('BsmtUnfSF', 0.9039965410782735),
#  ('2ndFlrSF', 0.8226806136452752),
#  ('Fireplaces', 0.7279684149050224),
#  ('HalfBath', 0.6863752733372056),
#  ('TotRmsAbvGrd', 0.6751222721533842),
#  ('TotalBsmtSF', 0.6135370560676916),
#  ('OverallCond', 0.598026614289392),
#  ('BsmtFullBath', 0.5926815400790177)]

# %%
features['HasWoodDeck'] = (features['WoodDeckSF'] == 0) * 1
features['HasOpenPorch'] = (features['OpenPorchSF'] == 0) * 1
features['HasEnclosedPorch'] = (features['EnclosedPorch'] == 0) * 1
features['Has3SsnPorch'] = (features['3SsnPorch'] == 0) * 1
features['HasScreenPorch'] = (features['ScreenPorch'] == 0) * 1
features['YearsSinceRemodel'] = features['YrSold'].astype(int) - features['YearRemodAdd'].astype(int)
features['Total_Home_Quality'] = features['OverallQual'] + features['OverallCond']
features = features.drop(['Utilities', 'Street', 'PoolQC'], axis=1)
features['TotalSF'] = features['TotalBsmtSF'] + features['1stFlrSF'] + features['2ndFlrSF']
features['YrBltAndRemod'] = features[['YearBuilt', 'YearRemodAdd']].apply(lambda x: x['YearBuilt'] if x['YearBuilt'] > x['YearRemodAdd'] else x['YearRemodAdd'], axis = 1)

features['Total_sqr_footage'] = (features['BsmtFinSF1'] + features['BsmtFinSF2'] +
                                 features['1stFlrSF'] + features['2ndFlrSF'])
features['Total_Bathrooms'] = (features['FullBath'] + (0.5 * features['HalfBath']) +
                               features['BsmtFullBath'] + (0.5 * features['BsmtHalfBath']))
features['Total_porch_sf'] = (features['OpenPorchSF'] + features['3SsnPorch'] +
                              features['EnclosedPorch'] + features['ScreenPorch'] +
                              features['WoodDeckSF'])

# %% [markdown]
# Scaling

# %%
def skew_fix(df):
    for col in num_cols:
        # skew fix
#         if stats.skew(df[col]) <= 0.5:
        df[col] = np.log1p(df[col])
    return df

# %%
num_cols = features.select_dtypes(numeric_dtypes).columns
features = skew_fix(features)
# Out:
# D:\Python\Anaconda\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# D:\Python\Anaconda\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
f, ax = plt.subplots(figsize=(8, 7))
ax.set_xscale("log")
ax = sns.boxplot(data=features[num_cols] , orient="h", palette="Set1")

# %%
X_train = features.iloc[:len(train)]
Y_train = target

# %%
len(X_train)
# Out:
# 1387

# %%
num_scaler = MinMaxScaler()
cat_enc = OneHotEncoder(drop='first')

# %%
cat_enc = cat_enc.fit(features.select_dtypes('object'))

# %%
cat_df = pd.DataFrame(data = cat_enc.transform(X_train.select_dtypes('object')).toarray(), columns = cat_enc.get_feature_names_out())

# %%
num_df = pd.DataFrame(data = num_scaler.fit_transform(X_train.select_dtypes(exclude = 'object')), columns=X_train.select_dtypes(exclude = 'object').columns)

# %%
X_train = pd.concat([cat_df, num_df], axis = 1)

# %% [markdown]
# Modelling

# %%
from sklearn.metrics import classification_report

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import KFold, cross_val_score

# %%
# Setup cross validation folds
kf = KFold(n_splits=4, random_state=777, shuffle=True)

# %%
# Define error metrics
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

def cv_rmse(model, X=X_train):
    rmse = np.sqrt(-cross_val_score(model, X, Y_train, scoring="neg_mean_squared_error", cv=kf))
    return (rmse)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.linear_model import Ridge, RidgeCV
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from mlxtend.regressor import StackingCVRegressor
from sklearn.metrics import mean_squared_error

# %%
# Light Gradient Boosting Regressor
lightgbm = LGBMRegressor(objective='regression', 
                       num_leaves=3,
                       learning_rate=0.01, 
                       n_estimators=5000,
                       max_depth = 7,
                       max_bin=200, 
                       bagging_fraction=0.8,
                       bagging_freq=4, 
                       bagging_seed=8,
                       feature_fraction=0.2,
                       feature_fraction_seed=8,
                       min_sum_hessian_in_leaf = 11,
                       verbose=-1,
                       random_state=777,
                       boosting_estimators = 'gbdt')
# XGBoost Regressor
xgboost = XGBRegressor(learning_rate=0.01,
                       n_estimators=6000,
                       max_depth=4,
                       min_child_weight=0,
                       gamma=0.6,
                       subsample=0.7,
                       colsample_bytree=0.7,
                       objective='reg:squarederror',
                       nthread=-1,
                       scale_pos_weight=1,
                       seed=27,
                       reg_alpha=0.00006,
                       random_state=42)

# Ridge Regressor
ridge_alphas = [1e-15, 1e-10, 1e-8, 9e-4, 7e-4, 5e-4, 3e-4, 1e-4, 1e-3, 5e-2, 1e-2, 0.1, 0.3, 1, 3, 5, 10, 15, 18, 20, 30, 50, 75, 100]
ridge = make_pipeline(RobustScaler(), RidgeCV(alphas=ridge_alphas, cv=kf))

# Support Vector Regressor
svr = make_pipeline(RobustScaler(), SVR(C= 20, epsilon= 0.008, gamma=0.0003))

# Gradient Boosting Regressor
gbr = GradientBoostingRegressor(n_estimators=6000,
                                learning_rate=0.01,
                                max_depth=4,
                                max_features='sqrt',
                                min_samples_leaf=15,
                                min_samples_split=10,
                                loss='huber',
                                random_state=42)  

# Random Forest Regressor
rf = RandomForestRegressor(n_estimators=1200,
                          max_depth=15,
                          min_samples_split=5,
                          min_samples_leaf=5,
                          max_features=None,
                          oob_score=True,
                          random_state=42)

# Stack up all the models above, optimized using xgboost
stack_gen = StackingCVRegressor(regressors=(xgboost, lightgbm, svr, ridge,  gbr),
                                meta_regressor=xgboost,
                                use_features_in_secondary=True)

# %%
ridge_model_full_data = ridge.fit(X_train, target)
# Out:
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.74907e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=2.02888e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=8.85343e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.11643e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %%
scores = {}

score = cv_rmse(lightgbm)
print("lightgbm: {:.4f} ({:.4f})".format(score.mean(), score.std()))
scores['lgb'] = (score.mean(), score.std())
# Out:
# [LightGBM] [Warning] Unknown parameter: boosting_estimators
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] Unknown parameter: boosting_estimators
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# ...

# %%
inv_boxcox(lgb_model_full_data.predict(X_train), lmbda)
# Out:
# array([204870.25407176, 180231.29518594, 215301.94833976, ...,
#        258566.77932753, 144883.62659728, 156294.8036172 ])

# %%
def blended_predictions(X):
    return ((0.1 * ridge_model_full_data.predict(X)) + \
            (0.1 * svr_model_full_data.predict(X)) + \
            (0.1 * gbr_model_full_data.predict(X)) + \
            (0.1 * xgb_model_full_data.predict(X)) + \
            (0.3 * lgb_model_full_data.predict(X)) + \
            (0.2 * rf_model_full_data.predict(X)) + \
            (0.1 * stack_gen_model.predict(np.array(X))))

# %%
ridge_model_full_data = ridge.fit(X_train, Y_train)
svr_model_full_data = svr.fit(X_train, Y_train)
lgb_model_full_data = lightgbm.fit(X_train, Y_train)
xgb_model_full_data = xgboost.fit(X_train, Y_train)
rf_model_full_data = rf.fit(X_train, Y_train)
gbr_model_full_data = gbr.fit(X_train, Y_train)
stack_gen_model = stack_gen.fit(np.array(X_train), np.array(Y_train))
# Out:
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.74907e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=2.02888e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=8.85343e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# D:\Python\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.11643e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# [LightGBM] [Warning] Unknown parameter: boosting_estimators
# ...

# %%
scores = {}
score = cv_rmse(lightgbm)
print("lightgbm: {:.4f} ({:.4f})".format(score.mean(), score.std()))
scores['lgb'] = (score.mean(), score.std())
score = cv_rmse(svr)
print("SVR: {:.4f} ({:.4f})".format(score.mean(), score.std()))
scores['svr'] = (score.mean(), score.std())
score = cv_rmse(xgboost)
print("xgboost: {:.4f} ({:.4f})".format(score.mean(), score.std()))
scores['xgb'] = (score.mean(), score.std())
score = cv_rmse(ridge)
print("ridge: {:.4f} ({:.4f})".format(score.mean(), score.std()))
scores['ridge'] = (score.mean(), score.std())
score = cv_rmse(rf)
print("rf: {:.4f} ({:.4f})".format(score.mean(), score.std()))
scores['rf'] = (score.mean(), score.std())
score = cv_rmse(gbr)
print("gbr: {:.4f} ({:.4f})".format(score.mean(), score.std()))
scores['gbr'] = (score.mean(), score.std())
# Out:
# [LightGBM] [Warning] Unknown parameter: boosting_estimators
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] Unknown parameter: boosting_estimators
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# ...

# %%
blended_score = rmsle(target, blended_predictions(X_train))
scores['blended'] = (blended_score, 0)
print('RMSLE score on train data:')
print(blended_score)
# Out:
# RMSLE score on train data:
# 0.0351460256564037

# %%
inv_boxcox(stack_gen_model.predict(X_train), lmbda)
# Out:
# D:\Python\Anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RobustScaler was fitted without feature names
#   warnings.warn(
# D:\Python\Anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RobustScaler was fitted without feature names
#   warnings.warn(
# D:\Python\Anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but GradientBoostingRegressor was fitted without feature names
#   warnings.warn(
# array([198304.9 , 178344.27, 209841.19, ..., 247166.6 , 142836.98,
#        153654.14], dtype=float32)

# %% [markdown]
# Обработка test

# %%
test['YearsSinceRemodel'].value_counts()
# Out:
#  0.000000    114
#  0.693147    106
#  4.043051     60
#  1.098612     52
#  1.609438     48
#             ...
#  2.944439      6
#  3.091042      5
#  3.135494      5
#  3.218876      4
# -inf           1
# Name: YearsSinceRemodel, Length: 62, dtype: int64

# %%
 test['YearsSinceRemodel'].apply(lambda x: x if x>=0 else 0)
# Out:
# 0       3.912023
# 1       3.970292
# 2       2.564949
# 3       2.564949
# 4       2.944439
#           ...
# 1454    3.610918
# 1455    3.610918
# 1456    2.397895
# 1457    2.708050
# 1458    2.564949
# Name: YearsSinceRemodel, Length: 1459, dtype: float64

# %%
test[test['YearsSinceRemodel'] <  0]
# Out:
# Empty DataFrame
# ...

# %%
test = features.iloc[len(train):]
cat_df_tr = pd.DataFrame(data = cat_enc.transform(test.select_dtypes('object')).toarray(), 
                         columns = cat_enc.get_feature_names_out())
num_df_tr = pd.DataFrame(data = num_scaler.transform(test.select_dtypes(exclude = 'object')), columns=test.select_dtypes(exclude = 'object').columns)
X_test = pd.concat([cat_df_tr, num_df_tr], axis = 1)

# %%
inv_boxcox(stack_gen_model.predict(X_train), lmbda)
# Out:
# D:\Python\Anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RobustScaler was fitted without feature names
#   warnings.warn(
# D:\Python\Anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RobustScaler was fitted without feature names
#   warnings.warn(
# D:\Python\Anaconda\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but GradientBoostingRegressor was fitted without feature names
#   warnings.warn(
# array([198304.9 , 178344.27, 209841.19, ..., 247166.6 , 142836.98,
#        153654.14], dtype=float32)

# %%
inv_boxcox(blended_predictions(X_test), lmbda)
# Out:
# array([123999.32818965, 161233.36351362, 181731.15021514, ...,
#        168053.83970497, 113733.18463914, 217595.84977077])

# %%
len(X_test)

# %%
blended_score = rmsle(Y_train, blended_predictions(X_train))
scores['blended'] = (blended_score, 0)
print('RMSLE score on train data:')
print(blended_score)
# Out:
# RMSLE score on train data:
# 0.0338291136442319

# %%
preds_blended = inv_boxcox(blended_predictions(X_test), lmbda)

# %%
submit = pd.read_csv('test.csv', usecols = [0])
submit['SalePrice'] = preds_blended
submit.head()
# Out:
#      Id      SalePrice
# 0  1461  123999.328190
# 1  1462  161233.363514
# 2  1463  181731.150215
# 3  1464  192718.796412
# 4  1465  188843.923787

# %%
submit.to_csv('Eleventh_sub.csv', index = False)
